# %%
from pathlib import Path
data_folder = Path("../Dataset")
output_folder = Path("../Dataset_rev")

file_users = data_folder / "users.csv"
output = output_folder / "users_rev.csv"

# %%
import pandas as pd

df_users = pd.read_csv(file_users)
df_users
# Out:
#      Unnamed: 0                                    id           created_at  \
# 0             0  37e369a8-4477-4d5d-acd7-4e3b8059586e  2021-03-23 00:24:53
# 1             1  27cf0bb6-3488-4662-916d-3ad04eeec9ca  2021-04-09 19:55:07
# 2             2  5ebd5e12-ba2a-4bf9-b7e4-92ad24711cd4  2021-04-08 21:48:45
# 3             3  30986592-0cbf-43bb-83ed-7501ab3bd373  2021-05-15 00:45:51
# 4             4  25b49125-34d1-4694-a4a9-8415bcc3567b  2021-07-05 04:08:53
# ..          ...                                   ...                  ...
# 995         995  d91c5e9a-ed7e-4f4a-b62b-ddabe069198a  2021-11-15 15:16:47
# 996         996  b80a25b8-a567-449c-af7a-420c46254112  2021-03-26 22:23:00
# 997         997  3d27e9ff-bc73-47f7-a51d-3047e6ec959f  2021-08-28 20:45:04
# 998         998  84e57e9b-4e2e-408b-a351-2aedf85a207c  2021-04-15 10:35:55
# 999         999  471e1687-07ba-4bb6-8341-839bd3d7c851  2021-05-01 09:08:13
#
#            class                 coordinates
# 0        Creator     ('36.76775', '2.95924')
# 1         Viewer    ('43.71032', '-1.05366')
# 2    Super Gamer        ('51.26', '-2.1875')
# 3        Creator   ('40.65538', '-74.38987')
# 4         Viewer   ('35.61452', '-88.81395')
# ..           ...                         ...
# 995       Viewer  ('-23.44361', '-51.87389')
# 996      Creator    ('54.48147', '53.47103')
# 997  Super Gamer    ('18.87813', '72.93924')
# 998       Viewer    ('31.92923', '34.86563')
# 999       Viewer   ('27.76056', '-15.58602')
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## cordinates -> latitude, longitude

# %%
latitude = [float(eval(coord)[0]) for coord in df_users['coordinates']]
longitude = [float(eval(coord)[1]) for coord in df_users['coordinates']]


df_users['user_latitude'] = latitude
df_users['user_longitude'] = longitude

df_users.drop(columns=['Unnamed: 0', 'coordinates'], inplace=True)
df_users.rename(columns={'created_at':'user_created_at'}, inplace=True)

# %%
df_users
# Out:
#                                        id      user_created_at        class  \
# 0    37e369a8-4477-4d5d-acd7-4e3b8059586e  2021-03-23 00:24:53      Creator
# 1    27cf0bb6-3488-4662-916d-3ad04eeec9ca  2021-04-09 19:55:07       Viewer
# 2    5ebd5e12-ba2a-4bf9-b7e4-92ad24711cd4  2021-04-08 21:48:45  Super Gamer
# 3    30986592-0cbf-43bb-83ed-7501ab3bd373  2021-05-15 00:45:51      Creator
# 4    25b49125-34d1-4694-a4a9-8415bcc3567b  2021-07-05 04:08:53       Viewer
# ..                                    ...                  ...          ...
# 995  d91c5e9a-ed7e-4f4a-b62b-ddabe069198a  2021-11-15 15:16:47       Viewer
# 996  b80a25b8-a567-449c-af7a-420c46254112  2021-03-26 22:23:00      Creator
# 997  3d27e9ff-bc73-47f7-a51d-3047e6ec959f  2021-08-28 20:45:04  Super Gamer
# 998  84e57e9b-4e2e-408b-a351-2aedf85a207c  2021-04-15 10:35:55       Viewer
# 999  471e1687-07ba-4bb6-8341-839bd3d7c851  2021-05-01 09:08:13       Viewer
#
#      user_latitude  user_longitude
# 0         36.76775         2.95924
# 1         43.71032        -1.05366
# 2         51.26000        -2.18750
# 3         40.65538       -74.38987
# 4         35.61452       -88.81395
# ..             ...             ...
# 995      -23.44361       -51.87389
# 996       54.48147        53.47103
# 997       18.87813        72.93924
# 998       31.92923        34.86563
# 999       27.76056       -15.58602
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## Get location from latitude and longitude

# %%
from geopy.geocoders import Nominatim

geolocator = Nominatim(user_agent="user_location")

search = [
    (df_users.iloc[i]['user_latitude'], df_users.iloc[i]['user_latitude'])
    for i in range(1000)
]

city = []
state = []
country = []

for s in search:
    location = geolocator.reverse(s, language="en")
    
    try:
        address = location.raw['address']

        # traverse the data
        city.append(address.get('city', ''))
        state.append(address.get('state', ''))
        country.append(address.get('country', ''))
        
    except:
        city.append('')
        state.append('')
        country.append('')

# %%
df_users['user_city'] = city
df_users['user_state'] = state
df_users['user_country'] = country

# %%
df_users
# Out:
#                                        id      user_created_at        class  \
# 0    37e369a8-4477-4d5d-acd7-4e3b8059586e  2021-03-23 00:24:53      Creator
# 1    27cf0bb6-3488-4662-916d-3ad04eeec9ca  2021-04-09 19:55:07       Viewer
# 2    5ebd5e12-ba2a-4bf9-b7e4-92ad24711cd4  2021-04-08 21:48:45  Super Gamer
# 3    30986592-0cbf-43bb-83ed-7501ab3bd373  2021-05-15 00:45:51      Creator
# 4    25b49125-34d1-4694-a4a9-8415bcc3567b  2021-07-05 04:08:53       Viewer
# ..                                    ...                  ...          ...
# 995  d91c5e9a-ed7e-4f4a-b62b-ddabe069198a  2021-11-15 15:16:47       Viewer
# 996  b80a25b8-a567-449c-af7a-420c46254112  2021-03-26 22:23:00      Creator
# 997  3d27e9ff-bc73-47f7-a51d-3047e6ec959f  2021-08-28 20:45:04  Super Gamer
# 998  84e57e9b-4e2e-408b-a351-2aedf85a207c  2021-04-15 10:35:55       Viewer
# 999  471e1687-07ba-4bb6-8341-839bd3d7c851  2021-05-01 09:08:13       Viewer
#
#      user_latitude  user_longitude user_city              user_state  \
# 0         36.76775         2.95924                Aleppo Governorate
# 1         43.71032        -1.05366                Kabardino-Balkaria
# 2         51.26000        -2.18750            West Kazakhstan Region
# 3         40.65538       -74.38987
# 4         35.61452       -88.81395
# ..             ...             ...       ...                     ...
# 995      -23.44361       -51.87389
# 996       54.48147        53.47103                     Bashkortostan
# 997       18.87813        72.93924                           Tibesti
# 998       31.92923        34.86563
# 999       27.76056       -15.58602                              Giza
#
#     user_country
# 0          Syria
# 1         Russia
# 2     Kazakhstan
# 3         Turkey
# 4          Syria
# ..           ...
# 995
# 996       Russia
# 997         Chad
# 998
# 999        Egypt
#
# [1000 rows x 8 columns]

# %%
df_users.to_csv(output)
